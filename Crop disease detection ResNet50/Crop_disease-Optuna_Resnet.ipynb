# %%
# !nvidia-smi
# Out:
# Thu May 22 23:52:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060 6GB  WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   37C    P8              5W /  120W |     568MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       464    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A      1064    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A      7500    C+G   ...Brave-Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A      8232    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A      9400    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A      9596    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A     10936    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     11360    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13708    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     14520    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     15952    C+G   ...64__v826wp6bftszj\TranslucentTB.exe      N/A      |
# |    0   N/A  N/A     17040    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     17188    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     17196    C+G   ...inaries\Win64\EpicGamesLauncher.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split
import os
import matplotlib.pyplot as plt
from PIL import Image
import torchvision.transforms as transforms

# %%
import random
import numpy as np
import torch

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(42)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Set the root path to your dataset
dataset_path = 'D:\DOCS\PYTHON\CropDisease\Crop___DIsease'  # ← change this to your actual path

# Get all class folders
class_folders = sorted(os.listdir(dataset_path))

# How many images to show
num_images_to_show = 32
images_per_row = 4

# Collect image paths and their labels
image_paths = []
labels = []

for class_name in class_folders:
    class_dir = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_dir):
        for img_name in os.listdir(class_dir)[:3]:  # take first 3 images per class
            if img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                image_paths.append(os.path.join(class_dir, img_name))
                labels.append(class_name)

# Plot using subplots
plt.figure(figsize=(15, 8))

for i in range(min(num_images_to_show, len(image_paths))):
    img = Image.open(image_paths[i])  # Open image using PIL
    img = img.convert('RGB')  # Ensure image is in RGB mode for displaying

    plt.subplot(num_images_to_show // images_per_row + 1, images_per_row, i + 1)
    plt.imshow(img)
    plt.title(labels[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def find_corrupted_images(root_dir):
    corrupted_files = []
    supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')

    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.lower().endswith(supported_extensions):
                file_path = os.path.join(subdir, file)
                try:
                    # Try to open and load the image
                    with Image.open(file_path) as img:
                        img.verify()  # verify() does not load image data but checks integrity
                except (IOError, SyntaxError) as e:
                    print(f"Corrupted file detected: {file_path}")
                    corrupted_files.append(file_path)
    
    if not corrupted_files:
        print("No corrupted images found!")
    else:
        print(f"\nTotal corrupted files found: {len(corrupted_files)}")

    return corrupted_files

# Change 'your_dataset_path' to your actual dataset directory
dataset_path = r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease'
corrupted_files = find_corrupted_images(dataset_path)
# Out:
# No corrupted images found!

# %%
crop_class_map = sorted(os.listdir(r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease'))
num_class = len(crop_class_map)
print(num_class)
print(crop_class_map)
# Out:
# 15
# ['Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy', 'Corn___Leaf_Blight', 'Invalid', 'Potato___Early_Blight', 'Potato___Healthy', 'Potato___Late_Blight', 'Rice___Brown_Spot', 'Rice___Healthy', 'Rice___Hispa', 'Rice___Leaf_Blast', 'Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust']

# %%
import os

def count_images_per_class(root_dir):
    supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')
    class_counts = {}

    # List all folders (classes) in root_dir
    for class_name in os.listdir(root_dir):
        class_path = os.path.join(root_dir, class_name)
        if os.path.isdir(class_path):
            count = 0
            for file in os.listdir(class_path):
                if file.lower().endswith(supported_extensions):
                    count += 1
            class_counts[class_name] = count

    return class_counts

# Replace with your dataset path
dataset_path = r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease'
counts = count_images_per_class(dataset_path)

for class_name, count in counts.items():
    print(f"Class '{class_name}': {count} images")

total_images = sum(counts.values())
print(f"\nTotal images in dataset: {total_images}")
# Out:
# Class 'Corn___Common_Rust': 3814 images
# Class 'Corn___Gray_Leaf_Spot': 3284 images
# Class 'Corn___Healthy': 3718 images
# Class 'Corn___Leaf_Blight': 3816 images
# Class 'Invalid': 1563 images
# Class 'Potato___Early_Blight': 3149 images
# Class 'Potato___Healthy': 2006 images
# Class 'Potato___Late_Blight': 3131 images
# Class 'Rice___Brown_Spot': 563 images
# Class 'Rice___Healthy': 523 images
# Class 'Rice___Hispa': 523 images
# Class 'Rice___Leaf_Blast': 1182 images
# Class 'Wheat___Brown_Rust': 1128 images
# Class 'Wheat___Healthy': 1497 images
# Class 'Wheat___Yellow_Rust': 1156 images
#
# Total images in dataset: 31053

# %%
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os
import torch

class CropDataset(Dataset):
    def __init__(self, root_dir, augment=False):
        self.root_dir = root_dir
        self.image_paths = []
        self.labels = []
        self.class_names = sorted(os.listdir(root_dir))
        self.augment = augment

        valid_extensions = ('.bmp', '.png', '.jpg', '.jpeg')

        # Image counts per class (make sure order matches class_names)
        class_image_counts = {
            'Corn___Common_Rust': 3814,
            'Corn___Gray_Leaf_Spot': 3284,
            'Corn___Healthy': 3718,
            'Corn___Leaf_Blight': 3816,
            'Invalid': 1563,
            'Potato___Early_Blight': 3149,
            'Potato___Healthy': 2006,
            'Potato___Late_Blight': 3131,
            'Rice___Brown_Spot': 563,
            'Rice___Healthy': 523,
            'Rice___Hispa': 523,
            'Rice___Leaf_Blast': 1182,
            'Wheat___Brown_Rust': 1128,
            'Wheat___Healthy': 1497,
            'Wheat___Yellow_Rust': 1156
        }

        # Define which classes need augmentation (threshold can be adjusted)
        self.augment_classes = {self.class_names.index(cls) for cls, count in class_image_counts.items() if count < 2000}

        for label, class_name in enumerate(self.class_names):
            class_path = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_path):
                if image_name.lower().endswith(valid_extensions):
                    image_path = os.path.join(class_path, image_name)
                    self.image_paths.append(image_path)
                    self.labels.append(label)

        # Data augmentation transformations
        self.augmentation_transforms = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.2),
            transforms.RandomRotation(degrees=20),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
            transforms.RandomResizedCrop(size=(224, 224), scale=(0.8, 1.0))
        ])

        # Standard preprocessing transformations
        self.preprocess_transforms = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]
            )
        ])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        label = self.labels[idx]
    
        try:
            image = Image.open(image_path).convert("RGB")
    
            # Apply augmentation only if enabled AND class is in augment_classes
            if self.augment and label in self.augment_classes:
                image = self.augmentation_transforms(image)
    
            # Apply standard preprocessing (resize, normalize, etc.)
            image = self.preprocess_transforms(image)
    
        except Exception as e:
            raise ValueError(f"Failed to load image: {image_path} — {e}")
    
        return image, torch.tensor(label, dtype=torch.long)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from torch.utils.data import Subset, DataLoader
import numpy as np
import random
import torch
import pickle

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Generator for reproducibility
g = torch.Generator()
g.manual_seed(42)

# ✅ Load full dataset without augmentation
full_dataset = CropDataset(root_dir=r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease', augment=False)
labels = full_dataset.labels

# ✅ Stratified split: Train / Val / Test
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15
total_size = len(labels)

# First split: Train vs Temp (val+test)
sss = StratifiedShuffleSplit(n_splits=1, test_size=(1 - train_ratio), random_state=42)
train_idx, temp_idx = next(sss.split(np.zeros(total_size), labels))

# Second split: Val vs Test
temp_labels = np.array(labels)[temp_idx]
sss_val_test = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(sss_val_test.split(np.zeros(len(temp_idx)), temp_labels))

# Map back to original indices
val_idx = np.array(temp_idx)[val_idx]
test_idx = np.array(temp_idx)[test_idx]

# ✅ Create dataset splits
train_dataset = CropDataset(root_dir=r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease', augment=True)
train_dataset = Subset(train_dataset, train_idx)

val_dataset = CropDataset(root_dir=r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease', augment=False)
val_dataset = Subset(val_dataset, val_idx)

test_dataset = CropDataset(root_dir=r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease', augment=False)
test_dataset = Subset(test_dataset, test_idx)

# ✅ Create DataLoaders (optimized)
batch_size = 32
num_workers = 0  # Adjust based on your CPU cores

full_train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True,
    num_workers=num_workers, pin_memory=True, worker_init_fn=seed_worker, generator=g
)

full_val_loader = DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False,
    num_workers=num_workers, pin_memory=True, worker_init_fn=seed_worker, generator=g
)

full_test_loader = DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False,
    num_workers=num_workers, pin_memory=True, worker_init_fn=seed_worker, generator=g
)

# ✅ Optional sanity check
print(f"Total: {total_size}, Train: {len(train_dataset)}, Val: {len(val_dataset)}, Test: {len(test_dataset)}")

# ================== Save Test Split ==================

# Path to save the test split indices
test_split_path = 'FINAL_test_split_indices.pkl'

# Save the test indices
with open(test_split_path, 'wb') as f:
    pickle.dump(list(test_idx), f)

print(f"Test split indices saved to {test_split_path}")
# Out:
# Total: 31053, Train: 21737, Val: 4658, Test: 4658
# Test split indices saved to FINAL_test_split_indices.pkl

# %%
# # ================== Dataset Split Consistency Check ==================

# # Function to split dataset and track splits
# def get_splits(dataset):
#     labels = dataset.labels
#     total_size = len(labels)

#     # First split: Train vs Temp (val+test)
#     sss = StratifiedShuffleSplit(n_splits=1, test_size=(1 - train_ratio), random_state=42)
#     train_idx, temp_idx = next(sss.split(np.zeros(total_size), labels))

#     # Second split: Val vs Test
#     temp_labels = np.array(labels)[temp_idx]
#     sss_val_test = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
#     val_idx, test_idx = next(sss_val_test.split(np.zeros(len(temp_idx)), temp_labels))

#     # Map back to original indices
#     val_idx = np.array(temp_idx)[val_idx]
#     test_idx = np.array(temp_idx)[test_idx]

#     train_images = sorted([dataset.image_paths[i] for i in train_idx])
#     val_images = sorted([dataset.image_paths[i] for i in val_idx])
#     test_images = sorted([dataset.image_paths[i] for i in test_idx])

#     return train_images, val_images, test_images

# # Reference split to compare against
# ref_train, ref_val, ref_test = get_splits(full_dataset)

# # Number of iterations to run
# num_iterations = 1000

# # Checking consistency across multiple runs
# for iteration in range(num_iterations):
#     current_train, current_val, current_test = get_splits(full_dataset)

#     if current_train != ref_train or current_val != ref_val or current_test != ref_test:
#         print(f"Inconsistency found in iteration {iteration}")
#         break
# else:
#     print("All splits are consistent across 1000 iterations")

# %%
# import shutil
# import os

# # Clear checkpoints
# shutil.rmtree('checkpoints', ignore_errors=True)
# os.makedirs('checkpoints', exist_ok=True)

# # Remove Optuna study database
# db_path = "optuna_study.db"
# if os.path.exists(db_path):
#     os.remove(db_path)

# print("Checkpoints and Optuna study cleared.")

# %%
# print("Cleaning up previous checkpoints and database...")
# checkpoint_dir = 'resnet_checkpoints'
# db_path = "resnet_study.db"

# # Delete checkpoint directory and all its contents
# if os.path.exists(checkpoint_dir):
#     shutil.rmtree(checkpoint_dir)
#     print(f"Deleted checkpoint directory: {checkpoint_dir}")
# else:
#     print(f"Checkpoint directory {checkpoint_dir} does not exist.")

# # Delete Optuna database
# if os.path.exists(db_path):
#     os.remove(db_path)
#     print(f"Deleted database: {db_path}")
# else:
#     print(f"Database {db_path} does not exist.")
# Out:
# Cleaning up previous checkpoints and database...
# Checkpoint directory resnet_checkpoints does not exist.
# Database resnet_study.db does not exist.

# %%
import optuna
from optuna.samplers import TPESampler
import torch
import torch.optim as optim
import torch.nn as nn
import torchvision.models as models
import os
import pickle
import gc  # For garbage collection

class ResNetFineTune(nn.Module):
    def __init__(self, num_class, hidden_units, dropout_rate):
        super().__init__()
        self.resnet = models.resnet50(pretrained=True)
        # Freeze early layers: conv1, bn1, layer1, layer2
        for param in self.resnet.conv1.parameters():
            param.requires_grad = False
        for param in self.resnet.bn1.parameters():
            param.requires_grad = False
        for param in self.resnet.layer1.parameters():
            param.requires_grad = False
        for param in self.resnet.layer2.parameters():
            param.requires_grad = False
        in_features = self.resnet.fc.in_features
        self.resnet.fc = nn.Sequential(
            nn.Linear(in_features, hidden_units),
            nn.BatchNorm1d(hidden_units),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_units, num_class)
        )
        for param in self.resnet.fc.parameters():
            param.requires_grad = True

    def forward(self, x):
        return self.resnet(x)

def objective(trial):
    try:
        print(f"Starting trial {trial.number}...")
        
        lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
        dropout_rate = trial.suggest_float("dropout", 0.2, 0.6)
        optimizer_name = trial.suggest_categorical("optimizer", ["SGD", "Adam", "AdamW", "RMSprop"])
        hidden_units = trial.suggest_int("hidden_units", 128, 1024, step=128)

        print(f"Hyperparams - lr: {lr:.6f}, dropout: {dropout_rate:.2f}, optimizer: {optimizer_name}, hidden: {hidden_units}")

        model = ResNetFineTune(num_class=num_class, hidden_units=hidden_units, dropout_rate=dropout_rate).to(device)
        criterion = nn.CrossEntropyLoss()

        if optimizer_name == "SGD":
            optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=1e-4, momentum=0.9)
        elif optimizer_name == "Adam":
            optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
        elif optimizer_name == "AdamW":
            optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        elif optimizer_name == "RMSprop":
            optimizer = optim.RMSprop(model.parameters(), lr=lr, weight_decay=1e-4)
        else:
            raise ValueError(f"Unsupported optimizer: {optimizer_name}")

        checkpoint_dir = 'resnet_checkpoints'
        os.makedirs(checkpoint_dir, exist_ok=True)
        checkpoint_path = os.path.join(checkpoint_dir, f"resnet_trial_{trial.number}.pth")
        best_accuracy = 0.0

        if os.path.exists(checkpoint_path):
            print(f"Resuming from checkpoint for trial {trial.number}...")
            checkpoint = torch.load(checkpoint_path)
            model.load_state_dict(checkpoint['model_state_dict'])
            optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
            best_accuracy = checkpoint['best_accuracy']

        print("Training...")
        for epoch in range(4):
            model.train()
            total_loss = 0
            for images, labels in full_train_loader:
                images, labels = images.to(device), labels.to(device)
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            avg_train_loss = total_loss / len(full_train_loader)
            print(f"Epoch [{epoch+1}/3], Train Loss: {avg_train_loss:.4f}")

            model.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                for images, labels in full_val_loader:
                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            accuracy = correct / total
            print(f"Epoch [{epoch+1}/3], Validation Accuracy: {accuracy:.4f}")

            if accuracy > best_accuracy:
                best_accuracy = accuracy
                checkpoint = {
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'best_accuracy': best_accuracy
                }
                torch.save(checkpoint, checkpoint_path)
                print(f"Checkpoint saved for trial {trial.number} at epoch {epoch+1}")

            trial.report(1.0 - accuracy, step=epoch)

            torch.cuda.empty_cache()
            gc.collect()

        return 1.0 - best_accuracy

    except torch.cuda.OutOfMemoryError:
        error_msg = "Out of Memory"
        print(f"Trial {trial.number} pruned: {error_msg}")
        trial.set_user_attr("skip_reason", error_msg)
        torch.cuda.empty_cache()
        gc.collect()
        raise optuna.exceptions.TrialPruned()

    except Exception as e:
        error_msg = str(e)
        print(f"Trial {trial.number} failed: {error_msg}")
        trial.set_user_attr("skip_reason", error_msg)
        raise optuna.exceptions.TrialPruned()

    finally:
        del model
        del optimizer
        torch.cuda.empty_cache()
        gc.collect()

# Optuna study setup
db_path = "resnet_study.db"
study = optuna.load_study(study_name="resnet_finetune_study", storage=f"sqlite:///{db_path}") if os.path.exists(db_path) else \
        optuna.create_study(study_name="resnet_finetune_study", direction="minimize", sampler=TPESampler(seed=42), storage=f"sqlite:///{db_path}")

print("Starting Optuna study...")
study.optimize(objective, n_trials=20)

print("\nBest trial:")
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print(f"  Params: {best_trial.params}")

# Check for skipped/pruned trials and their reasons
print("\nSkipped Trials Report:")
for trial in study.get_trials(states=[optuna.trial.TrialState.PRUNED]):
    reason = trial.user_attrs.get("skip_reason", "Unknown reason")
    print(f"Trial {trial.number}: {reason}")

print("Completed Optuna study with logging of skipped trials.")

best_trial = study.best_trial
best_params = best_trial.params
print(best_params)
# Out:
# [I 2025-05-22 23:53:02,400] A new study created in RDB with name: resnet_finetune_study
# C:\Users\Mushfiq\anaconda3\envs\PT\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Mushfiq\anaconda3\envs\PT\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Starting Optuna study...
# Starting trial 0...
# Hyperparams - lr: 0.000561, dropout: 0.58, optimizer: SGD, hidden: 128
# Training...
# Epoch [1/3], Train Loss: 0.6203
# Epoch [1/3], Validation Accuracy: 0.9530
# Checkpoint saved for trial 0 at epoch 1
# Epoch [2/3], Train Loss: 0.2422
# Epoch [2/3], Validation Accuracy: 0.9667
# Checkpoint saved for trial 0 at epoch 2
# Epoch [3/3], Train Loss: 0.1708
# Epoch [3/3], Validation Accuracy: 0.9721
# Checkpoint saved for trial 0 at epoch 3
# Epoch [4/3], Train Loss: 0.1434
# Epoch [4/3], Validation Accuracy: 0.9766
# Checkpoint saved for trial 0 at epoch 4
# [I 2025-05-23 01:40:45,735] Trial 0 finished with value: 0.023400601116359 and parameters: {'lr': 0.0005611516415334506, 'dropout': 0.5802857225639664, 'optimizer': 'SGD', 'hidden_units': 128}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 1...
# Hyperparams - lr: 0.005399, dropout: 0.44, optimizer: AdamW, hidden: 256
# Training...
# Epoch [1/3], Train Loss: 0.4481
# Epoch [1/3], Validation Accuracy: 0.9184
# Checkpoint saved for trial 1 at epoch 1
# Epoch [2/3], Train Loss: 0.2274
# Epoch [2/3], Validation Accuracy: 0.9388
# Checkpoint saved for trial 1 at epoch 2
# Epoch [3/3], Train Loss: 0.1795
# Epoch [3/3], Validation Accuracy: 0.9450
# Checkpoint saved for trial 1 at epoch 3
# Epoch [4/3], Train Loss: 0.1634
# Epoch [4/3], Validation Accuracy: 0.9343
# [I 2025-05-23 03:21:35,723] Trial 1 finished with value: 0.054959209961356836 and parameters: {'lr': 0.005399484409787433, 'dropout': 0.4404460046972835, 'optimizer': 'AdamW', 'hidden_units': 256}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 2...
# Hyperparams - lr: 0.000231, dropout: 0.27, optimizer: Adam, hidden: 640
# Training...
# Epoch [1/3], Train Loss: 0.2142
# Epoch [1/3], Validation Accuracy: 0.9609
# Checkpoint saved for trial 2 at epoch 1
# Epoch [2/3], Train Loss: 0.1255
# Epoch [2/3], Validation Accuracy: 0.9504
# Epoch [3/3], Train Loss: 0.0974
# Epoch [3/3], Validation Accuracy: 0.9680
# Checkpoint saved for trial 2 at epoch 3
# Epoch [4/3], Train Loss: 0.0907
# Epoch [4/3], Validation Accuracy: 0.9558
# [I 2025-05-23 05:05:33,370] Trial 2 finished with value: 0.03198797767282091 and parameters: {'lr': 0.0002310201887845295, 'dropout': 0.27336180394137355, 'optimizer': 'Adam', 'hidden_units': 640}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 3...
# Hyperparams - lr: 0.000190, dropout: 0.32, optimizer: AdamW, hidden: 640
# Training...
# Epoch [1/3], Train Loss: 0.2079
# Epoch [1/3], Validation Accuracy: 0.9631
# Checkpoint saved for trial 3 at epoch 1
# Epoch [2/3], Train Loss: 0.1162
# Epoch [2/3], Validation Accuracy: 0.9691
# Checkpoint saved for trial 3 at epoch 2
# Epoch [3/3], Train Loss: 0.0915
# Epoch [3/3], Validation Accuracy: 0.9676
# Epoch [4/3], Train Loss: 0.0833
# Epoch [4/3], Validation Accuracy: 0.9513
# [I 2025-05-23 06:47:47,454] Trial 3 finished with value: 0.030914555603263172 and parameters: {'lr': 0.00019010245319870352, 'dropout': 0.3168578594140873, 'optimizer': 'AdamW', 'hidden_units': 640}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 4...
# Hyperparams - lr: 0.001530, dropout: 0.22, optimizer: RMSprop, hidden: 1024
# Training...
# Epoch [1/3], Train Loss: 0.4301
# Epoch [1/3], Validation Accuracy: 0.8778
# Checkpoint saved for trial 4 at epoch 1
# Epoch [2/3], Train Loss: 0.2051
# Epoch [2/3], Validation Accuracy: 0.9427
# Checkpoint saved for trial 4 at epoch 2
# Epoch [3/3], Train Loss: 0.1798
# Epoch [3/3], Validation Accuracy: 0.9427
# Epoch [4/3], Train Loss: 0.1596
# Epoch [4/3], Validation Accuracy: 0.8014
# [I 2025-05-23 08:29:35,969] Trial 4 finished with value: 0.05732073851438391 and parameters: {'lr': 0.0015304852121831463, 'dropout': 0.2185801650879991, 'optimizer': 'RMSprop', 'hidden_units': 1024}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 5...
# Hyperparams - lr: 0.004138, dropout: 0.32, optimizer: Adam, hidden: 512
# Training...
# Epoch [1/3], Train Loss: 0.4318
# Epoch [1/3], Validation Accuracy: 0.9133
# Checkpoint saved for trial 5 at epoch 1
# Epoch [2/3], Train Loss: 0.2498
# Epoch [2/3], Validation Accuracy: 0.9298
# Checkpoint saved for trial 5 at epoch 2
# Epoch [3/3], Train Loss: 0.2107
# Epoch [3/3], Validation Accuracy: 0.9390
# Checkpoint saved for trial 5 at epoch 3
# Epoch [4/3], Train Loss: 0.1965
# Epoch [4/3], Validation Accuracy: 0.9468
# Checkpoint saved for trial 5 at epoch 4
# [I 2025-05-23 10:13:32,099] Trial 5 finished with value: 0.05324173465006443 and parameters: {'lr': 0.004138040112561018, 'dropout': 0.3218455076693483, 'optimizer': 'Adam', 'hidden_units': 512}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 6...
# Hyperparams - lr: 0.000117, dropout: 0.56, optimizer: Adam, hidden: 640
# Training...
# Epoch [1/3], Train Loss: 0.2226
# Epoch [1/3], Validation Accuracy: 0.9669
# Checkpoint saved for trial 6 at epoch 1
# Epoch [2/3], Train Loss: 0.1128
# Epoch [2/3], Validation Accuracy: 0.9714
# Checkpoint saved for trial 6 at epoch 2
# Epoch [3/3], Train Loss: 0.0960
# Epoch [3/3], Validation Accuracy: 0.9687
# Epoch [4/3], Train Loss: 0.0828
# Epoch [4/3], Validation Accuracy: 0.9680
# [I 2025-05-23 11:55:42,688] Trial 6 finished with value: 0.0285530270502361 and parameters: {'lr': 0.00011715937392307068, 'dropout': 0.5637281608315128, 'optimizer': 'Adam', 'hidden_units': 640}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 7...
# Hyperparams - lr: 0.000234, dropout: 0.59, optimizer: Adam, hidden: 1024
# Training...
# Epoch [1/3], Train Loss: 0.2313
# Epoch [1/3], Validation Accuracy: 0.9641
# Checkpoint saved for trial 7 at epoch 1
# Epoch [2/3], Train Loss: 0.1241
# Epoch [2/3], Validation Accuracy: 0.9665
# Checkpoint saved for trial 7 at epoch 2
# Epoch [3/3], Train Loss: 0.1031
# Epoch [3/3], Validation Accuracy: 0.9704
# Checkpoint saved for trial 7 at epoch 3
# Epoch [4/3], Train Loss: 0.0928
# Epoch [4/3], Validation Accuracy: 0.9757
# Checkpoint saved for trial 7 at epoch 4
# [I 2025-05-23 13:37:49,080] Trial 7 finished with value: 0.024259338772005146 and parameters: {'lr': 0.00023426581058204064, 'dropout': 0.5878338511058234, 'optimizer': 'Adam', 'hidden_units': 1024}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 8...
# Hyperparams - lr: 0.000150, dropout: 0.28, optimizer: AdamW, hidden: 896
# Training...
# Epoch [1/3], Train Loss: 0.1973
# Epoch [1/3], Validation Accuracy: 0.9594
# Checkpoint saved for trial 8 at epoch 1
# Epoch [2/3], Train Loss: 0.1035
# Epoch [2/3], Validation Accuracy: 0.9665
# Checkpoint saved for trial 8 at epoch 2
# Epoch [3/3], Train Loss: 0.0888
# Epoch [3/3], Validation Accuracy: 0.9708
# Checkpoint saved for trial 8 at epoch 3
# Epoch [4/3], Train Loss: 0.0846
# Epoch [4/3], Validation Accuracy: 0.9704
# [I 2025-05-23 15:19:51,796] Trial 8 finished with value: 0.029197080291970767 and parameters: {'lr': 0.00015030900645056822, 'dropout': 0.2783931449676581, 'optimizer': 'AdamW', 'hidden_units': 896}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 9...
# Hyperparams - lr: 0.000517, dropout: 0.31, optimizer: AdamW, hidden: 1024
# Training...
# Epoch [1/3], Train Loss: 0.2552
# Epoch [1/3], Validation Accuracy: 0.9483
# Checkpoint saved for trial 9 at epoch 1
# Epoch [2/3], Train Loss: 0.1346
# Epoch [2/3], Validation Accuracy: 0.9538
# Checkpoint saved for trial 9 at epoch 2
# Epoch [3/3], Train Loss: 0.1105
# Epoch [3/3], Validation Accuracy: 0.9599
# Checkpoint saved for trial 9 at epoch 3
# Epoch [4/3], Train Loss: 0.0966
# Epoch [4/3], Validation Accuracy: 0.9650
# Checkpoint saved for trial 9 at epoch 4
# [I 2025-05-23 17:01:06,927] Trial 9 finished with value: 0.03499355946758265 and parameters: {'lr': 0.0005170191786366995, 'dropout': 0.3123738038749523, 'optimizer': 'AdamW', 'hidden_units': 1024}. Best is trial 0 with value: 0.023400601116359.
# Starting trial 10...
# Hyperparams - lr: 0.001065, dropout: 0.48, optimizer: SGD, hidden: 128
# Training...
# Epoch [1/3], Train Loss: 0.4404
# Epoch [1/3], Validation Accuracy: 0.9665
# Checkpoint saved for trial 10 at epoch 1
# Epoch [2/3], Train Loss: 0.1525
# Epoch [2/3], Validation Accuracy: 0.9712
# Checkpoint saved for trial 10 at epoch 2
# Epoch [3/3], Train Loss: 0.1125
# Epoch [3/3], Validation Accuracy: 0.9757
# Checkpoint saved for trial 10 at epoch 3
# Epoch [4/3], Train Loss: 0.0931
# Epoch [4/3], Validation Accuracy: 0.9777
# Checkpoint saved for trial 10 at epoch 4
# [I 2025-05-23 18:42:39,667] Trial 10 finished with value: 0.02232717904680115 and parameters: {'lr': 0.0010649438604541353, 'dropout': 0.48245346078229184, 'optimizer': 'SGD', 'hidden_units': 128}. Best is trial 10 with value: 0.02232717904680115.
# Starting trial 11...
# Hyperparams - lr: 0.001064, dropout: 0.49, optimizer: SGD, hidden: 128
# Training...
# Epoch [1/3], Train Loss: 0.4361
# Epoch [1/3], Validation Accuracy: 0.9624
# Checkpoint saved for trial 11 at epoch 1
# Epoch [2/3], Train Loss: 0.1527
# Epoch [2/3], Validation Accuracy: 0.9721
# Checkpoint saved for trial 11 at epoch 2
# Epoch [3/3], Train Loss: 0.1137
# Epoch [3/3], Validation Accuracy: 0.9740
# Checkpoint saved for trial 11 at epoch 3
# Epoch [4/3], Train Loss: 0.0953
# Epoch [4/3], Validation Accuracy: 0.9781
# Checkpoint saved for trial 11 at epoch 4
# [I 2025-05-23 20:25:48,103] Trial 11 finished with value: 0.021897810218978075 and parameters: {'lr': 0.00106359571750338, 'dropout': 0.4932793377618082, 'optimizer': 'SGD', 'hidden_units': 128}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 12...
# Hyperparams - lr: 0.001794, dropout: 0.48, optimizer: SGD, hidden: 128
# Training...
# Epoch [1/3], Train Loss: 0.3561
# Epoch [1/3], Validation Accuracy: 0.9654
# Checkpoint saved for trial 12 at epoch 1
# Epoch [2/3], Train Loss: 0.1258
# Epoch [2/3], Validation Accuracy: 0.9714
# Checkpoint saved for trial 12 at epoch 2
# Epoch [3/3], Train Loss: 0.0954
# Epoch [3/3], Validation Accuracy: 0.9751
# Checkpoint saved for trial 12 at epoch 3
# Epoch [4/3], Train Loss: 0.0802
# Epoch [4/3], Validation Accuracy: 0.9755
# Checkpoint saved for trial 12 at epoch 4
# [I 2025-05-23 22:06:28,866] Trial 12 finished with value: 0.024474023185916738 and parameters: {'lr': 0.0017937722033317504, 'dropout': 0.4804927713237949, 'optimizer': 'SGD', 'hidden_units': 128}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 13...
# Hyperparams - lr: 0.000841, dropout: 0.50, optimizer: SGD, hidden: 384
# Training...
# Epoch [1/3], Train Loss: 0.3368
# Epoch [1/3], Validation Accuracy: 0.9672
# Checkpoint saved for trial 13 at epoch 1
# Epoch [2/3], Train Loss: 0.1175
# Epoch [2/3], Validation Accuracy: 0.9736
# Checkpoint saved for trial 13 at epoch 2
# Epoch [3/3], Train Loss: 0.0909
# Epoch [3/3], Validation Accuracy: 0.9760
# Checkpoint saved for trial 13 at epoch 3
# Epoch [4/3], Train Loss: 0.0773
# Epoch [4/3], Validation Accuracy: 0.9779
# Checkpoint saved for trial 13 at epoch 4
# [I 2025-05-23 23:47:01,739] Trial 13 finished with value: 0.022112494632889668 and parameters: {'lr': 0.0008407931655574886, 'dropout': 0.49991454199342644, 'optimizer': 'SGD', 'hidden_units': 384}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 14...
# Hyperparams - lr: 0.002532, dropout: 0.51, optimizer: SGD, hidden: 384
# Training...
# Epoch [1/3], Train Loss: 0.2237
# Epoch [1/3], Validation Accuracy: 0.9729
# Checkpoint saved for trial 14 at epoch 1
# Epoch [2/3], Train Loss: 0.0964
# Epoch [2/3], Validation Accuracy: 0.9749
# Checkpoint saved for trial 14 at epoch 2
# Epoch [3/3], Train Loss: 0.0734
# Epoch [3/3], Validation Accuracy: 0.9740
# Epoch [4/3], Train Loss: 0.0652
# Epoch [4/3], Validation Accuracy: 0.9781
# Checkpoint saved for trial 14 at epoch 4
# [I 2025-05-24 01:27:21,454] Trial 14 finished with value: 0.021897810218978075 and parameters: {'lr': 0.002532181823811885, 'dropout': 0.5147215572718324, 'optimizer': 'SGD', 'hidden_units': 384}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 15...
# Hyperparams - lr: 0.002702, dropout: 0.39, optimizer: SGD, hidden: 384
# Training...
# Epoch [1/3], Train Loss: 0.2192
# Epoch [1/3], Validation Accuracy: 0.9676
# Checkpoint saved for trial 15 at epoch 1
# Epoch [2/3], Train Loss: 0.0883
# Epoch [2/3], Validation Accuracy: 0.9747
# Checkpoint saved for trial 15 at epoch 2
# Epoch [3/3], Train Loss: 0.0720
# Epoch [3/3], Validation Accuracy: 0.9781
# Checkpoint saved for trial 15 at epoch 3
# Epoch [4/3], Train Loss: 0.0611
# Epoch [4/3], Validation Accuracy: 0.9757
# [I 2025-05-24 03:08:29,215] Trial 15 finished with value: 0.021897810218978075 and parameters: {'lr': 0.0027024082567909573, 'dropout': 0.3851596282680102, 'optimizer': 'SGD', 'hidden_units': 384}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 16...
# Hyperparams - lr: 0.008793, dropout: 0.52, optimizer: RMSprop, hidden: 384
# Training...
# Epoch [1/3], Train Loss: 0.7175
# Epoch [1/3], Validation Accuracy: 0.4818
# Checkpoint saved for trial 16 at epoch 1
# Epoch [2/3], Train Loss: 0.3299
# Epoch [2/3], Validation Accuracy: 0.2289
# Epoch [3/3], Train Loss: 0.2768
# Epoch [3/3], Validation Accuracy: 0.4167
# Epoch [4/3], Train Loss: 0.2570
# Epoch [4/3], Validation Accuracy: 0.0646
# [I 2025-05-24 04:49:27,233] Trial 16 finished with value: 0.5182481751824817 and parameters: {'lr': 0.008792755995011581, 'dropout': 0.5206526069830318, 'optimizer': 'RMSprop', 'hidden_units': 384}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 17...
# Hyperparams - lr: 0.002005, dropout: 0.41, optimizer: SGD, hidden: 256
# Training...
# Epoch [1/3], Train Loss: 0.2566
# Epoch [1/3], Validation Accuracy: 0.9704
# Checkpoint saved for trial 17 at epoch 1
# Epoch [2/3], Train Loss: 0.0959
# Epoch [2/3], Validation Accuracy: 0.9714
# Checkpoint saved for trial 17 at epoch 2
# Epoch [3/3], Train Loss: 0.0773
# Epoch [3/3], Validation Accuracy: 0.9779
# Checkpoint saved for trial 17 at epoch 3
# Epoch [4/3], Train Loss: 0.0652
# Epoch [4/3], Validation Accuracy: 0.9762
# [I 2025-05-24 06:31:50,918] Trial 17 finished with value: 0.022112494632889668 and parameters: {'lr': 0.002004617910720447, 'dropout': 0.40598816560837725, 'optimizer': 'SGD', 'hidden_units': 256}. Best is trial 11 with value: 0.021897810218978075.
# Starting trial 18...
# Hyperparams - lr: 0.003297, dropout: 0.54, optimizer: SGD, hidden: 256
# Training...
# Epoch [1/3], Train Loss: 0.2454
# Epoch [1/3], Validation Accuracy: 0.9652
# Checkpoint saved for trial 18 at epoch 1
# Epoch [2/3], Train Loss: 0.1013
# Epoch [2/3], Validation Accuracy: 0.9680
# Checkpoint saved for trial 18 at epoch 2
# Epoch [3/3], Train Loss: 0.0794
# Epoch [3/3], Validation Accuracy: 0.9757
# Checkpoint saved for trial 18 at epoch 3
# Epoch [4/3], Train Loss: 0.0713
# Epoch [4/3], Validation Accuracy: 0.9798
# Checkpoint saved for trial 18 at epoch 4
# [I 2025-05-24 08:14:23,408] Trial 18 finished with value: 0.02018033490768567 and parameters: {'lr': 0.003296946749245102, 'dropout': 0.5367089005477355, 'optimizer': 'SGD', 'hidden_units': 256}. Best is trial 18 with value: 0.02018033490768567.
# Starting trial 19...
# Hyperparams - lr: 0.000459, dropout: 0.55, optimizer: SGD, hidden: 256
# Training...
# Epoch [1/3], Train Loss: 0.5116
# Epoch [1/3], Validation Accuracy: 0.9556
# Checkpoint saved for trial 19 at epoch 1
# Epoch [2/3], Train Loss: 0.1902
# Epoch [2/3], Validation Accuracy: 0.9682
# Checkpoint saved for trial 19 at epoch 2
# Epoch [3/3], Train Loss: 0.1353
# Epoch [3/3], Validation Accuracy: 0.9706
# Checkpoint saved for trial 19 at epoch 3
# Epoch [4/3], Train Loss: 0.1081
# Epoch [4/3], Validation Accuracy: 0.9727
# Checkpoint saved for trial 19 at epoch 4
# [I 2025-05-24 09:56:01,958] Trial 19 finished with value: 0.02726492056676688 and parameters: {'lr': 0.0004590137376977682, 'dropout': 0.5475969587223795, 'optimizer': 'SGD', 'hidden_units': 256}. Best is trial 18 with value: 0.02018033490768567.
# Best trial:
#   Value: 0.02018033490768567
#   Params: {'lr': 0.003296946749245102, 'dropout': 0.5367089005477355, 'optimizer': 'SGD', 'hidden_units': 256}
#
# Skipped Trials Report:
# Completed Optuna study with logging of skipped trials.
# {'lr': 0.003296946749245102, 'dropout': 0.5367089005477355, 'optimizer': 'SGD', 'hidden_units': 256}

# %%
# Load the Optuna study to get the best trial
db_path = "resnet_study.db"
study = optuna.load_study(study_name="resnet_finetune_study", storage=f"sqlite:///{db_path}")

# Get the best trial number
best_trial_number = study.best_trial.number
checkpoint_dir = 'resnet_checkpoints'

# Check if the checkpoint directory exists
if os.path.exists(checkpoint_dir):
    print("Cleaning up unnecessary checkpoints...")
    for file in os.listdir(checkpoint_dir):
        # Skip the checkpoint file for the best trial
        if file == f"resnet_trial_{best_trial_number}.pth":
            continue
        # Delete all other checkpoint files
        if file.startswith('resnet_trial_') and file.endswith('.pth'):
            file_path = os.path.join(checkpoint_dir, file)
            os.remove(file_path)
            print(f"Deleted checkpoint: {file_path}")
    print("Checkpoint cleanup completed.")
else:
    print(f"Checkpoint directory {checkpoint_dir} does not exist.")
# Out:
# Cleaning up unnecessary checkpoints...
# Deleted checkpoint: resnet_checkpoints\resnet_trial_0.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_1.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_10.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_11.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_12.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_13.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_14.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_15.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_16.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_17.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_19.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_2.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_3.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_4.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_5.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_6.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_7.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_8.pth
# Deleted checkpoint: resnet_checkpoints\resnet_trial_9.pth
# Checkpoint cleanup completed.

# %%
import sqlite3

conn = sqlite3.connect("optuna_study.db")
cursor = conn.cursor()
cursor.execute("SELECT trial_id, state FROM trials")
print(cursor.fetchall())
conn.close()
# Out:
# [(1, 'FAIL'), (2, 'COMPLETE'), (3, 'COMPLETE'), (4, 'COMPLETE'), (5, 'COMPLETE'), (6, 'COMPLETE'), (7, 'COMPLETE'), (8, 'COMPLETE'), (9, 'COMPLETE'), (10, 'RUNNING'), (11, 'COMPLETE'), (12, 'COMPLETE'), (13, 'COMPLETE'), (14, 'COMPLETE'), (15, 'COMPLETE'), (16, 'COMPLETE'), (17, 'COMPLETE'), (18, 'COMPLETE'), (19, 'COMPLETE'), (20, 'COMPLETE'), (21, 'COMPLETE'), (22, 'COMPLETE'), (23, 'COMPLETE'), (24, 'COMPLETE'), (25, 'COMPLETE'), (26, 'FAIL')]

# %%
print(best_params)
lr = best_params['lr']
dropout_rate = best_params['dropout']
optimizer_name = best_params['optimizer']
hidden_units = best_params['hidden_units']
epochs = 30
# Out:
# {'lr': 0.003296946749245102, 'dropout': 0.5367089005477355, 'optimizer': 'SGD', 'hidden_units': 256}

# %%
import torch.nn as nn
import torchvision.models as models

class ResNetFineTune(nn.Module):
    def __init__(self, num_class, hidden_units, dropout_rate):
        super().__init__()
        self.resnet = models.resnet50(pretrained=True)
        # Freeze early layers: conv1, bn1, layer1, layer2
        for param in self.resnet.conv1.parameters():
            param.requires_grad = False
        for param in self.resnet.bn1.parameters():
            param.requires_grad = False
        for param in self.resnet.layer1.parameters():
            param.requires_grad = False
        for param in self.resnet.layer2.parameters():
            param.requires_grad = False
        in_features = self.resnet.fc.in_features
        self.resnet.fc = nn.Sequential(
            nn.Linear(in_features, hidden_units),
            nn.BatchNorm1d(hidden_units),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_units, num_class)
        )
        for param in self.resnet.fc.parameters():
            param.requires_grad = True

    def forward(self, x):
        return self.resnet(x)

# %%
from torchsummary import summary
# Define class counts (same as in CropDataset)
class_counts = [3814, 3284, 3718, 3816, 1563, 3149, 2006, 3131, 563, 523, 523, 1182, 1128, 1497, 1156]

# Calculate class weights (inverse frequency)
class_weights = torch.tensor([1.0 / count for count in class_counts], dtype=torch.float).to(device)

model = ResNetFineTune(num_class=num_class, hidden_units=hidden_units, dropout_rate=dropout_rate).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)  # Add class weights to loss

# Print model summary
summary(model, input_size=(3, 224, 224))

# Initialize optimizer based on Optuna's best optimizer
if optimizer_name == "SGD":
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=1e-4, momentum=0.9)
elif optimizer_name == "Adam":
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
elif optimizer_name == "AdamW":
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
elif optimizer_name == "RMSprop":
    optimizer = optim.RMSprop(model.parameters(), lr=lr, weight_decay=1e-4)
else:
    raise ValueError(f"Unsupported optimizer: {optimizer_name}")

# Learning rate scheduler (same as original code)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-164            [-1, 512, 7, 7]           1,024
#             ReLU-165            [-1, 512, 7, 7]               0
#           Conv2d-166            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-167            [-1, 512, 7, 7]           1,024
#             ReLU-168            [-1, 512, 7, 7]               0
#           Conv2d-169           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 7, 7]           4,096
#             ReLU-171           [-1, 2048, 7, 7]               0
#       Bottleneck-172           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                  [-1, 256]         524,544
#      BatchNorm1d-175                  [-1, 256]             512
#             ReLU-176                  [-1, 256]               0
#          Dropout-177                  [-1, 256]               0
#           Linear-178                   [-1, 15]           3,855
#           ResNet-179                   [-1, 15]               0
# ================================================================
# Total params: 24,036,943
# Trainable params: 22,592,015
# Non-trainable params: 1,444,928
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 286.56
# Params size (MB): 91.69
# Estimated Total Size (MB): 378.83
# ----------------------------------------------------------------
# C:\Users\Mushfiq\anaconda3\envs\PT\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
# !nvidia-smi
# Out:
# Sat May 24 09:56:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060 6GB  WDDM  |   00000000:01:00.0  On |                  N/A |
# | 22%   68C    P2             33W /  120W |     880MiB /   6144MiB |     13%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1064    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A      8232    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A      9400    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A      9596    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A     10692    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     10936    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A     12768    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     13708    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     14520    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     15952    C+G   ...64__v826wp6bftszj\TranslucentTB.exe      N/A      |
# |    0   N/A  N/A     15980      C   ...ushfiq\anaconda3\envs\PT\python.exe      N/A      |
# |    0   N/A  N/A     16916    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     17040    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A     17188    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     17196    C+G   ...inaries\Win64\EpicGamesLauncher.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os

# Paths to your checkpoint and best model
checkpoint_path = "checkpoint.pth"
best_model_path = "best_model.pth"

# Check if the checkpoint file exists and remove it
if os.path.exists(checkpoint_path):
    print(f"Deleting old checkpoint: {checkpoint_path}")
    os.remove(checkpoint_path)

# Check if the best model file exists and remove it
if os.path.exists(best_model_path):
    print(f"Deleting old best model: {best_model_path}")
    os.remove(best_model_path)

# Optionally, if you want to clear any other unnecessary files, add them here
# Example: os.remove("another_checkpoint.pth")

print("Old checkpoints deleted. Ready to start fresh training.")
# Out:
# Old checkpoints deleted. Ready to start fresh training.

# %%
import time
from tqdm import tqdm
# Initialize lists for tracking metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
best_val_loss = float('inf')

# File paths
checkpoint_path = "FINAL_crop_checkpoint_optuna_resnet.pth"
best_model_path = "FINAL_crop_best_model_resnet_optuna.pth"
final_model_path = "FINAL_crop_final_model_resnet_optuna.pth"
final_weights_path = "FINAL_crop_final_weights_resnet_optuna.pth"

# Early stopping parameters
patience = 5
early_stop_counter = 0
start_epoch = 0

# Check if a checkpoint exists
if os.path.exists(checkpoint_path):
    print("Resuming training from the last checkpoint...")
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    start_epoch = checkpoint['epoch'] + 1
    best_val_loss = checkpoint['best_val_loss']
    early_stop_counter = checkpoint['early_stop_counter']
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    # Load accuracies if present
    train_accuracies = checkpoint.get('train_accuracies', [])
    val_accuracies = checkpoint.get('val_accuracies', [])
    # Load class weights if saved
    if 'class_weights' in checkpoint:
        class_weights = checkpoint['class_weights'].to(device)
        criterion = nn.CrossEntropyLoss(weight=class_weights)
    print(f"Resumed from epoch {start_epoch}")
else:
    print("No checkpoint found. Starting training from scratch...")

for epoch in range(start_epoch, epochs):
    start_time = time.time()
    print(f"Epoch {epoch+1}/{epochs} started")
    
    # Training Phase
    model.train()
    print('Training...')
    total_train_loss = 0
    correct_train = 0
    total_train = 0

    for batch_features, batch_labels in tqdm(full_train_loader, desc='Training', leave=False):
        batch_features, batch_labels = batch_features.to(device), batch_labels.to(device)
        outputs = model(batch_features)
        loss = criterion(outputs, batch_labels)  # Weighted loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += batch_labels.size(0)
        correct_train += (predicted == batch_labels).sum().item()

    avg_train_loss = total_train_loss / len(full_train_loader)
    train_accuracy = 100 * correct_train / total_train
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)

    # Validation Phase
    model.eval()  # Fixed: Added parentheses
    print('Validating...')
    total_val_loss = 0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for val_features, val_labels in tqdm(full_val_loader, desc='Validating', leave=False):
            val_features, val_labels = val_features.to(device), val_labels.to(device)
            val_outputs = model(val_features)
            val_loss = criterion(val_outputs, val_labels)  # Weighted loss
            total_val_loss += val_loss.item()

            # Calculate validation accuracy
            _, predicted = torch.max(val_outputs.data, 1)
            total_val += val_labels.size(0)
            correct_val += (predicted == val_labels).sum().item()

    avg_val_loss = total_val_loss / len(full_val_loader)
    val_accuracy = 100 * correct_val / total_val
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)

    # Print loss and accuracy
    print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, "
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")

    # Check for improvement and save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), best_model_path)
        print(f"Best model saved with validation loss: {best_val_loss:.4f}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"Early stopping counter: {early_stop_counter}/{patience}")

    # Save checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'best_val_loss': best_val_loss,
        'early_stop_counter': early_stop_counter,
        'train_losses': train_losses,
        'val_losses': val_losses,
        'train_accuracies': train_accuracies,
        'val_accuracies': val_accuracies,
        'class_weights': class_weights
    }
    torch.save(checkpoint, checkpoint_path)
    print(f"Checkpoint saved at epoch {epoch+1}")

    # Check early stopping
    if early_stop_counter >= patience:
        print("Early stopping triggered. Loading best model...")
        model.load_state_dict(torch.load(best_model_path))
        break

    # GPU Memory Monitoring
    print(f"GPU Memory Allocated: {torch.cuda.memory_allocated(device) / 1024**2:.2f} MB")

    # Step the learning rate scheduler
    scheduler.step(avg_val_loss)

    print(f"Epoch duration: {time.time() - start_time:.2f} seconds")

# Save the final model and weights
torch.save(model.state_dict(), final_weights_path)
torch.save(model, final_model_path)

print("Training complete. Models saved as:")
print(f"- Best model: {best_model_path}")
print(f"- Final model: {final_model_path}")
print(f"- Final weights only: {final_weights_path}")
# Out:
# No checkpoint found. Starting training from scratch...
# Epoch 1/30 started
# Training...
# Validating...
# Epoch [1/30], Train Loss: 0.4626, Train Accuracy: 91.81%, Validation Loss: 0.2446, Validation Accuracy: 96.76%
# Best model saved with validation loss: 0.2446
# Checkpoint saved at epoch 1
# GPU Memory Allocated: 305.17 MB
# Epoch duration: 1522.12 seconds
# Epoch 2/30 started
# Training...
# Validating...
# Epoch [2/30], Train Loss: 0.2640, Train Accuracy: 96.02%, Validation Loss: 0.2184, Validation Accuracy: 96.63%
# Best model saved with validation loss: 0.2184
# Checkpoint saved at epoch 2
# GPU Memory Allocated: 307.10 MB
# Epoch duration: 1521.69 seconds
# Epoch 3/30 started
# Training...
# Validating...
# Epoch [3/30], Train Loss: 0.2206, Train Accuracy: 96.77%, Validation Loss: 0.2480, Validation Accuracy: 97.04%
# Early stopping counter: 1/5
# Checkpoint saved at epoch 3
# GPU Memory Allocated: 305.21 MB
# Epoch duration: 1527.91 seconds
# Epoch 4/30 started
# Training...
# Validating...
# Epoch [4/30], Train Loss: 0.2060, Train Accuracy: 97.17%, Validation Loss: 0.1693, Validation Accuracy: 97.25%
# Best model saved with validation loss: 0.1693
# Checkpoint saved at epoch 4
# GPU Memory Allocated: 306.22 MB
# Epoch duration: 1526.89 seconds
# Epoch 5/30 started
# Training...
# Validating...
# Epoch [5/30], Train Loss: 0.1966, Train Accuracy: 97.31%, Validation Loss: 0.1774, Validation Accuracy: 97.34%
# Early stopping counter: 1/5
# Checkpoint saved at epoch 5
# GPU Memory Allocated: 308.48 MB
# Epoch duration: 1521.05 seconds
# Epoch 6/30 started
# Training...
# Validating...
# Epoch [6/30], Train Loss: 0.1810, Train Accuracy: 97.57%, Validation Loss: 0.1658, Validation Accuracy: 97.45%
# Best model saved with validation loss: 0.1658
# Checkpoint saved at epoch 6
# GPU Memory Allocated: 308.02 MB
# Epoch duration: 1522.82 seconds
# Epoch 7/30 started
# Training...
# Validating...
# Epoch [7/30], Train Loss: 0.1779, Train Accuracy: 97.65%, Validation Loss: 0.1441, Validation Accuracy: 98.05%
# Best model saved with validation loss: 0.1441
# Checkpoint saved at epoch 7
# GPU Memory Allocated: 308.02 MB
# Epoch duration: 1527.38 seconds
# Epoch 8/30 started
# Training...
# Validating...
# Epoch [8/30], Train Loss: 0.1679, Train Accuracy: 97.78%, Validation Loss: 0.1643, Validation Accuracy: 97.27%
# Early stopping counter: 1/5
# Checkpoint saved at epoch 8
# GPU Memory Allocated: 307.77 MB
# Epoch duration: 1527.53 seconds
# Epoch 9/30 started
# Training...
# Validating...
# Epoch [9/30], Train Loss: 0.1726, Train Accuracy: 97.86%, Validation Loss: 0.1540, Validation Accuracy: 97.92%
# Early stopping counter: 2/5
# Checkpoint saved at epoch 9
# GPU Memory Allocated: 306.19 MB
# Epoch duration: 1528.26 seconds
# Epoch 10/30 started
# Training...
# Validating...
# Epoch [10/30], Train Loss: 0.1545, Train Accuracy: 97.99%, Validation Loss: 0.1551, Validation Accuracy: 98.00%
# Early stopping counter: 3/5
# Checkpoint saved at epoch 10
# GPU Memory Allocated: 308.27 MB
# Epoch duration: 1525.04 seconds
# Epoch 11/30 started
# Training...
# Validating...
# Epoch [11/30], Train Loss: 0.1596, Train Accuracy: 97.84%, Validation Loss: 0.2492, Validation Accuracy: 97.19%
# Early stopping counter: 4/5
# Checkpoint saved at epoch 11
# GPU Memory Allocated: 307.13 MB
# Epoch duration: 1526.97 seconds
# Epoch 12/30 started
# Training...
# Validating...
# Epoch [12/30], Train Loss: 0.1344, Train Accuracy: 98.16%, Validation Loss: 0.1303, Validation Accuracy: 98.13%
# Best model saved with validation loss: 0.1303
# Checkpoint saved at epoch 12
# GPU Memory Allocated: 306.93 MB
# Epoch duration: 1541.60 seconds
# Epoch 13/30 started
# Training...
# Validating...
# Epoch [13/30], Train Loss: 0.1177, Train Accuracy: 98.53%, Validation Loss: 0.1401, Validation Accuracy: 98.13%
# Early stopping counter: 1/5
# Checkpoint saved at epoch 13
# GPU Memory Allocated: 306.76 MB
# Epoch duration: 1529.73 seconds
# Epoch 14/30 started
# Training...
# Validating...
# Epoch [14/30], Train Loss: 0.1178, Train Accuracy: 98.44%, Validation Loss: 0.1518, Validation Accuracy: 98.09%
# Early stopping counter: 2/5
# Checkpoint saved at epoch 14
# GPU Memory Allocated: 305.90 MB
# Epoch duration: 1532.90 seconds
# Epoch 15/30 started
# Training...
# Validating...
# Epoch [15/30], Train Loss: 0.1158, Train Accuracy: 98.65%, Validation Loss: 0.1303, Validation Accuracy: 98.22%
# Early stopping counter: 3/5
# Checkpoint saved at epoch 15
# GPU Memory Allocated: 306.85 MB
# Epoch duration: 1530.38 seconds
# Epoch 16/30 started
# Training...
# Validating...
# Epoch [16/30], Train Loss: 0.1101, Train Accuracy: 98.68%, Validation Loss: 0.1355, Validation Accuracy: 98.37%
# Early stopping counter: 4/5
# Checkpoint saved at epoch 16
# GPU Memory Allocated: 306.76 MB
# Epoch duration: 1531.47 seconds
# Epoch 17/30 started
# Training...
# Validating...
# C:\Users\Mushfiq\AppData\Local\Temp\ipykernel_15980\1943559633.py:131: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# Epoch [17/30], Train Loss: 0.0971, Train Accuracy: 98.73%, Validation Loss: 0.1377, Validation Accuracy: 98.05%
# Early stopping counter: 5/5
# Checkpoint saved at epoch 17
# Early stopping triggered. Loading best model...
# Training complete. Models saved as:
# - Best model: FINAL_crop_best_model_resnet_optuna.pth
# - Final model: FINAL_crop_final_model_resnet_optuna.pth
# - Final weights only: FINAL_crop_final_weights_resnet_optuna.pth

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch

# Evaluate best model
try:
    model.load_state_dict(torch.load(best_model_path, weights_only=True))
except FileNotFoundError:
    raise FileNotFoundError(f"Best model not found at {best_model_path}")
except Exception as e:
    raise RuntimeError(f"Failed to load model from {best_model_path}: {e}")

model.eval()
total_test_loss = 0
correct = 0
total = 0
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in full_test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        total_test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Compute metrics
avg_test_loss = total_test_loss / len(full_test_loader)
test_accuracy = 100 * correct / total
precision = precision_score(all_labels, all_preds, average='macro')
recall = recall_score(all_labels, all_preds, average='macro')
f1 = f1_score(all_labels, all_preds, average='macro')
f1_per_class = f1_score(all_labels, all_preds, average=None)
class_names = full_dataset.class_names  # From CropDataset

# Compute confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Print metrics
print(f"Final Evaluation Results | "
      f"Test Loss: {avg_test_loss:.4f} | "
      f"Accuracy: {test_accuracy:.2f}% | "
      f"Precision: {precision:.4f} | Recall: {recall:.4f} | F1 Score: {f1:.4f}")
print("\nPer-class F1 Scores:")
for class_name, f1_score in zip(class_names, f1_per_class):
    print(f"{class_name}: {f1_score:.4f}")

# Plot confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Final Evaluation Results | Test Loss: 0.1408 | Accuracy: 97.92% | Precision: 0.9402 | Recall: 0.9444 | F1 Score: 0.9405
#
# Per-class F1 Scores:
# Corn___Common_Rust: 1.0000
# Corn___Gray_Leaf_Spot: 0.9918
# Corn___Healthy: 1.0000
# Corn___Leaf_Blight: 0.9939
# Invalid: 0.9957
# Potato___Early_Blight: 1.0000
# Potato___Healthy: 1.0000
# Potato___Late_Blight: 1.0000
# Rice___Brown_Spot: 0.8824
# Rice___Healthy: 0.7342
# Rice___Hispa: 0.6632
# Rice___Leaf_Blast: 0.8677
# Wheat___Brown_Rust: 0.9941
# Wheat___Healthy: 0.9955
# Wheat___Yellow_Rust: 0.9884

# %%
# Plotting: Training vs Validation Loss and Accuracy side by side
completed_epochs = len(train_losses)
epochs = list(range(1, completed_epochs + 1))

plt.figure(figsize=(14, 5))

# Subplot 1: Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.plot(epochs, val_losses, label='Validation Loss', color='red', marker='o', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(alpha=0.3)

# Subplot 2: Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Training Accuracy', color='blue')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red', marker='o', linestyle='--')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# ROC curve

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Assuming num_class is defined (number of classes)
# And all_labels, all_preds already collected

# 1. Get probabilities
all_probs = []

model.eval()
with torch.no_grad():
    for images, labels in full_test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        all_probs.extend(probs.cpu().numpy())

# 2. Binarize labels for multi-class ROC
all_labels_bin = label_binarize(all_labels, classes=list(range(num_class)))
all_probs = np.array(all_probs)

# 3. Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_class):
    fpr[i], tpr[i], _ = roc_curve(all_labels_bin[:, i], all_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 4. Plot
plt.figure(figsize=(10, 8))
for i in range(num_class):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Assuming you already created the test_dataset using random_split

# Access the dataset inside the Subset object
test_image_paths = [test_dataset.dataset.image_paths[i] for i in test_dataset.indices[:30]]

# Print image paths
for idx, path in enumerate(test_image_paths):
    print(f"Image {idx+1}: {path}")
# Out:
# Image 1: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\655010d0-0bf7-4cba-8ebe-591a8bc5f552___RS_Early.B 7668_flipTB.JPG
# Image 2: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\7348d45f-96ba-454e-b0eb-084d0284f718___RS_NLB 4242(1).JPG
# Image 3: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Late_Blight\98a806fd-2839-4069-b40b-08522c34ccdc___RS_LB 3032.JPG
# Image 4: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Rice___Leaf_Blast\IMG_4853.jpg
# Image 5: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\ec769dd1-532c-4f81-b677-6b7b4d0d7606___RS_NLB 4140_180deg(1).JPG
# Image 6: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Healthy\b7214149-73ad-481e-9227-c9fe77f10477___R.S_HL 7896 copy 2.jpg
# Image 7: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\2ccec9ab-60e1-4b79-bfdc-b33d387db907___RS_GLSp 4576_90deg.JPG
# Image 8: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Invalid\flower_0048.jpg
# Image 9: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Rice___Leaf_Blast\IMG_20190419_110208.jpg
# Image 10: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Late_Blight\53e33b6d-9fc5-441b-b638-3bf067f92a99___RS_LB 2753.JPG
# Image 11: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\3c53ba48-cb78-4803-b01c-7d10ea13284c___RS_GLSp 4611_90deg.JPG
# Image 12: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\af3bb3a3-e022-45f3-b209-6b3b53f13a47___RS_Early.B 7333_flipTB.JPG
# Image 13: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\ef5c7a36-4a79-419f-94e9-ad1120a68dad___RS_NLB 3932 copy_flipTB(1).jpg
# Image 14: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Healthy\0f9d8b9a-a49d-4641-b956-dc0963d7b6da___R.S_HL 8148 copy 2(1).jpg
# Image 15: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\7348d45f-96ba-454e-b0eb-084d0284f718___RS_NLB 4242_flipTB.JPG
# Image 16: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\f9580dc3-d5d9-4990-a64d-3974a9d1c687___RS_Early.B 8755_flipTB.JPG
# Image 17: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\e60c841c-2a10-4a27-a2e9-2604fb9ead83___RS_NLB 4192(1).JPG
# Image 18: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Late_Blight\42b19bb3-68b6-4c46-a626-f7480718360a___RS_LB 4686_180deg.JPG
# Image 19: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Healthy\098a17fd-0351-4f0f-a4a8-6f2a638b4afb___R.S_HL 7897 copy 2_flipLR(1).jpg
# Image 20: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\d1f9878a-eea5-4008-8a1d-b3a88e2654b8___RS_GLSp 4640_new30degFlipLR(1).JPG
# Image 21: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\98d0dbe1-2532-419e-9cc4-1ef0da68fb0e___RS_GLSp 4452_270deg.JPG
# Image 22: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Wheat___Brown_Rust\Brown_rust745.jpg
# Image 23: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\image (488).JPG
# Image 24: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Wheat___Healthy\Healthy865.jpg
# Image 25: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Healthy\ab0fc79a-bd95-406c-a008-21985ddcb71a___R.S_HL 7985 copy 2_flipLR(1).jpg
# Image 26: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\91721448-8786-49f6-a66d-d410fe714676___RS_Early.B 7725_flipTB.JPG
# Image 27: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Healthy\bb04f738-1848-4dda-8834-384a48b335cd___RS_HL 1765_270deg.JPG
# Image 28: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Wheat___Yellow_Rust\Yellow_rust936.jpg
# Image 29: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\d63f0a92-e489-4acd-b5df-847a83172abc___RS_GLSp 4607_270deg.JPG
# Image 30: D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Common_Rust\RS_Rust 2545_flipLR(1).JPG

# %%
from torchvision import transforms
import matplotlib.pyplot as plt
import torch
from PIL import Image
import os

# ---------------------------
# Configuration
# ---------------------------

# Sample multiple image paths (adjust the paths as needed)
image_paths = [
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Early_Blight\655010d0-0bf7-4cba-8ebe-591a8bc5f552___RS_Early.B 7668_flipTB.JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\7348d45f-96ba-454e-b0eb-084d0284f718___RS_NLB 4242(1).JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Late_Blight\98a806fd-2839-4069-b40b-08522c34ccdc___RS_LB 3032.JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Rice___Leaf_Blast\IMG_4853.jpg',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Leaf_Blight\ec769dd1-532c-4f81-b677-6b7b4d0d7606___RS_NLB 4140_180deg(1).JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Healthy\b7214149-73ad-481e-9227-c9fe77f10477___R.S_HL 7896 copy 2.jpg',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\2ccec9ab-60e1-4b79-bfdc-b33d387db907___RS_GLSp 4576_90deg.JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Invalid\flower_0048.jpg',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Rice___Leaf_Blast\IMG_20190419_110208.jpg',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Potato___Late_Blight\53e33b6d-9fc5-441b-b638-3bf067f92a99___RS_LB 2753.JPG',
    r'D:\DOCS\PYTHON\CropDisease\Crop___DIsease\Corn___Gray_Leaf_Spot\3c53ba48-cb78-4803-b01c-7d10ea13284c___RS_GLSp 4611_90deg.JPG',
]


# Load your model here
# model = YourModelClass(...)
# model.load_state_dict(torch.load("your_model_path.pth"))
model.to(device)
model.eval()


# ---------------------------
# Helper functions
# ---------------------------

def load_and_preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  # Resize for VGG/ResNet input
            transforms.ToTensor(),
            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],  # ImageNet normalization
                std=[0.229, 0.224, 0.225])
    ])
    image = Image.open(image_path).convert('RGB')
    return transform(image).unsqueeze(0)  # Add batch dimension

def get_actual_class(image_path):
    return os.path.basename(os.path.dirname(image_path))

# ---------------------------
# Prediction and Display
# ---------------------------

# Set up the subplot grid
n_images = len(image_paths)
cols = 3
rows = (n_images + cols - 1) // cols  # Calculate number of rows

fig, axes = plt.subplots(rows, cols, figsize=(15, 10))
axes = axes.flatten()

for idx, image_path in enumerate(image_paths):
    actual_class = get_actual_class(image_path)
    image_tensor = load_and_preprocess_image(image_path).to(device)
    
    with torch.no_grad():
        outputs = model(image_tensor)
        _, predicted_idx = torch.max(outputs, 1)
        predicted_class = crop_class_map[predicted_idx.item()]
    
    # Reopen image for display (no transformation)
    img_display = Image.open(image_path)
    
    # Display image and prediction
    axes[idx].imshow(img_display)
    axes[idx].set_title(f"Actual: {actual_class}\nPredicted: {predicted_class}")
    axes[idx].axis('off')

# Hide any remaining axes if the number of images is less than the grid size
for j in range(idx + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
